# %% [markdown]
# <a href="https://colab.research.google.com/github/SJSUMS/SMFAI/blob/main/code/dataLoader.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Dataset
#
# **System Testing**
# target cloth + ground truth(ref_person & cloth)
# * [VVT L.I.P](https://drive.google.com/drive/folders/1LHqJH2vwOY1PoGpjUu8C2RqbnWJ9EK-f?usp=sharing)
#
# **Reference Person**
# * [Fashionpedia: FGVC7](https://www.kaggle.com/c/imaterialist-fashion-2020-fgvc7/data?select=train)
#
# * [DeepFashion](http://mmlab.ie.cuhk.edu.hk/projects/DeepFashion/FashionSynthesis.html)
#
# * [Video]
#
# **Target Cloth**
# [Fashion Product](https://www.kaggle.com/paramaggarwal/fashion-product-images-dataset)

# %%
# mount
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### load data

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

fpath = '/content/drive/Shareddrives/298 Master Project/dataset/'

# %%
data_df = pd.read_csv(fpath+'FPI/fpi.csv')
data_df
# Out:
#          category  ...                                               link
# 0         Topwear  ...  http://assets.myntassets.com/v1/images/style/p...
# 1      Bottomwear  ...  http://assets.myntassets.com/v1/images/style/p...
# 2      Bottomwear  ...  http://assets.myntassets.com/v1/images/style/p...
# 3         Topwear  ...  http://assets.myntassets.com/v1/images/style/p...
# 4         Topwear  ...  http://assets.myntassets.com/v1/images/style/p...
# ...           ...  ...                                                ...
# 18571     Topwear  ...  http://assets.myntassets.com/v1/images/style/p...
# 18572     Topwear  ...  http://assets.myntassets.com/v1/images/style/p...
# 18573     Topwear  ...  http://assets.myntassets.com/v1/images/style/p...
# 18574     Topwear  ...  http://assets.myntassets.com/v1/images/style/p...
# 18575     Topwear  ...  http://assets.myntassets.com/v1/images/style/p...
#
# [18576 rows x 5 columns]

# %% [markdown]
# ## view imgs

# %%
img_url = data_df['link'][0]
target_size = (240,180)

import requests
import shutil
import os

_, ext = os.path.splitext(img_url)
    
r = requests.get(img_url, stream=True)
with open('temp.' + ext, 'wb') as f:
    r.raw.decode_content = True
    shutil.copyfileobj(r.raw, f)

img = image.load_img('temp.' + ext, target_size=target_size)

img
# Out:
# <PIL.Image.Image image mode=RGB size=180x240 at 0x7FC9603DF290>
